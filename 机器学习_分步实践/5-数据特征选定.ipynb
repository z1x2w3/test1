# %% [markdown]
# # 单变量特征选定
# 使用统计的方法，看每个自变量（列）和因变量（列）的相关性，指定个数，选出相关性高的。

# %%
# 通过卡方检验选定数据特征
from pandas import read_csv
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# 导入数据
filename = 'pima_data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
# 将数据分为输入数据和输出结果
array = data.values
X = array[:, 0:8]
Y = array[:, 8]

# 特征选定
test = SelectKBest(score_func = chi2, k = 4)
fit = test.fit(X, Y)

set_printoptions(precision = 3)
print(fit.scores_)
features = fit.transform(X)
print(features)
# Out:
# [ 111.52  1411.887   17.605   53.108 2175.565  127.669    5.393  181.304]
# [[148.    0.   33.6  50. ]
#  [ 85.    0.   26.6  31. ]
#  [183.    0.   23.3  32. ]
#  ...
#  [121.  112.   26.2  30. ]
#  [126.    0.   30.1  47. ]
#  [ 93.    0.   30.4  23. ]]

# %% [markdown]
# # 递归特征消除
# 使用所有特征训练基模型；去除某一特征，对比结果情况，看差异大不大

# %%
import warnings
warnings.filterwarnings('ignore')

# 通过递归消除来选定特征
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# 导入数据
filename = 'pima_data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
# 将数据分为输入数据和输出结果
array = data.values
X = array[:, 0:8]
Y = array[:, 8]

# 特征选定
model = LogisticRegression()
rfe = RFE(estimator = model, n_features_to_select = 3) # 原来是RFE(model, 3)
fit = rfe.fit(X, Y)

print("特征个数：")
print(fit.n_features_)
print("被选定的特征：")
print(fit.support_)
print("特征排名：")
print(fit.ranking_)
# Out:
# 特征个数：
# 3
# 被选定的特征：
# [ True False False False False  True  True False]
# 特征排名：
# [1 2 4 5 6 1 1 3]

# %% [markdown]
# # 主成分分析PCA
# 使用线性代数来转换压缩数据，通常被称作数据降维

# %%
# 通过主要成分分析选定数据特征
from pandas import read_csv
from sklearn.decomposition import PCA
# 导入数据
filename = 'pima_data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
# 将数据分为输入数据和输出结果
array = data.values
X = array[:, 0:8]
Y = array[:, 8]

# 特征选定
pca = PCA(n_components = 4)
fit = pca.fit(X)

print("解释方差：%s" % fit.explained_variance_ratio_)
print(fit.components_)
# Out:
# 解释方差：[0.88854663 0.06159078 0.02579012 0.01308614]
# [[-2.02176587e-03  9.78115765e-02  1.60930503e-02  6.07566861e-02
#    9.93110844e-01  1.40108085e-02  5.37167919e-04 -3.56474430e-03]
#  [-2.26488861e-02 -9.72210040e-01 -1.41909330e-01  5.78614699e-02
#    9.46266913e-02 -4.69729766e-02 -8.16804621e-04 -1.40168181e-01]
#  [-2.24649003e-02  1.43428710e-01 -9.22467192e-01 -3.07013055e-01
#    2.09773019e-02 -1.32444542e-01 -6.39983017e-04 -1.25454310e-01]
#  [-4.90459604e-02  1.19830016e-01 -2.62742788e-01  8.84369380e-01
#   -6.55503615e-02  1.92801728e-01  2.69908637e-03 -3.01024330e-01]]

# %% [markdown]
# # 特征重要性

# %%
# 通过决策树计算特征的重要性
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier
# 导入数据
filename = 'pima_data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names = names)
# 将数据分为输入数据和输出结果
array = data.values
X = array[:, 0:8]
Y = array[:, 8]

# 特征选定
model = ExtraTreesClassifier()
fit = model.fit(X, Y)

print(fit.feature_importances_)
# Out:
# [0.109 0.241 0.098 0.08  0.074 0.139 0.118 0.141]

# %% [markdown]
# ## 选合适的就行，不用每个都用
